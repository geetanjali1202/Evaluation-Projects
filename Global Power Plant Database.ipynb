# %% [markdown]
# # Global Power Plant Database

# %% [markdown]
# Project Description
# The Global Power Plant Database is a comprehensive, open source database of power plants around the world. It centralizes power plant data to make it easier to navigate, compare and draw insights for one’s own analysis. The database covers approximately 14,000 power plants from 3 countries(USA, AUS, INDIA) and includes thermal plants (e.g. coal, gas, oil, nuclear, biomass, waste, geothermal) and renewables (e.g. hydro, wind, solar). Each power plant is geolocated and entries contain information on plant capacity, generation, ownership, and fuel type. It will be continuously updated as data becomes available.
# Key attributes of the database
# The database includes the following indicators:
#
# •	`country` (text): 3 character country code corresponding to the ISO 3166-1 alpha-3 specification [5]
# •	`country_long` (text): longer form of the country designation
# •	`name` (text): name or title of the power plant, generally in Romanized form
# •	`gppd_idnr` (text): 10 or 12 character identifier for the power plant
# •	`capacity_mw` (number): electrical generating capacity in megawatts
# •	`latitude` (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
# •	`longitude` (number): geolocation in decimal degrees; WGS84 (EPSG:4326)
# •	`primary_fuel` (text): energy source used in primary electricity generation or export
# •	`other_fuel1` (text): energy source used in electricity generation or export
# •	`other_fuel2` (text): energy source used in electricity generation or export
# •	`other_fuel3` (text): energy source used in electricity generation or export
# •	 `commissioning_year` (number): year of plant operation, weighted by unit-capacity when data is available
# •	`owner` (text): majority shareholder of the power plant, generally in Romanized form
# •	`source` (text): entity reporting the data; could be an organization, report, or document, generally in Romanized form
# •	`url` (text): web document corresponding to the `source` field
# •	`geolocation_source` (text): attribution for geolocation information
# •	`wepp_id` (text): a reference to a unique plant identifier in the widely-used PLATTS-WEPP database.
# •	`year_of_capacity_data` (number): year the capacity information was reported
# •	`generation_gwh_2013` (number): electricity generation in gigawatt-hours reported for the year 2013
# •	`generation_gwh_2014` (number): electricity generation in gigawatt-hours reported for the year 2014
# •	`generation_gwh_2015` (number): electricity generation in gigawatt-hours reported for the year 2015
# •	`generation_gwh_2016` (number): electricity generation in gigawatt-hours reported for the year 2016
# •	`generation_gwh_2017` (number): electricity generation in gigawatt-hours reported for the year 2017
# •	`generation_gwh_2018` (number): electricity generation in gigawatt-hours reported for the year 2018
# •	`generation_gwh_2019` (number): electricity generation in gigawatt-hours reported for the year 2019
# •	`generation_data_source` (text): attribution for the reported generation information
# •	`estimated_generation_gwh_2013` (number): estimated electricity generation in gigawatt-hours for the year 2013
# •	`estimated_generation_gwh_2014` (number): estimated electricity generation in gigawatt-hours for the year 2014
# •	`estimated_generation_gwh_2015` (number): estimated electricity generation in gigawatt-hours for the year 2015
# •	`estimated_generation_gwh_2016` (number): estimated electricity generation in gigawatt-hours for the year 2016
# •	`estimated_generation_gwh_2017` (number): estimated electricity generation in gigawatt-hours for the year 2017
# •	'estimated_generation_note_2013` (text): label of the model/method used to estimate generation for the year 2013
# •	`estimated_generation_note_2014` (text): label of the model/method used to estimate generation for the year 2014
# •	`estimated_generation_note_2015` (text): label of the model/method used to estimate generation for the year 2015
# •	`estimated_generation_note_2016` (text): label of the model/method used to estimate generation for the year 2016
# •	`estimated_generation_note_2017` (text): label of the model/method used to estimate generation for the year 2017
# Fuel Type Aggregation
# We define the "Fuel Type" attribute of our database based on common fuel categories.
# Prediction :   Make two prediction  1) Primary Fuel    2) capacity_mw
#
# Hint : Use pandas methods to combine all the datasets and then start working on this project.
#
#
# Dataset Link-
# •	https://github.com/FlipRoboTechnologies/ML_-Datasets/tree/main/Global%20Power%20Plant%20Database

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("/Users/geetanjalijoshi/Desktop/Datatrained /datasets /global_thermal_dataset/database_AUS.csv")
df2 = pd.read_csv("/Users/geetanjalijoshi/Desktop/Datatrained /datasets /global_thermal_dataset/database_IND.csv")
df3 = pd.read_csv("/Users/geetanjalijoshi/Desktop/Datatrained /datasets /global_thermal_dataset/database_USA.csv")

# %%
df1.head()
# Out:
#   country country_long                   name   gppd_idnr  capacity_mw  \
# 0     AUS    Australia       Adelaide Airport  AUS0000433         0.11
# 1     AUS    Australia   Adelaide Showgrounds  AUS0000432         1.00
# 2     AUS    Australia       Albany Wind Farm  AUS0000065        21.60
# 3     AUS    Australia  Alice Springs Airport  AUS0000469         0.24
# 4     AUS    Australia           Amcor Gawler  AUS0000231         4.00
#
#    latitude  longitude primary_fuel  other_fuel1  other_fuel2  ...  \
# 0  -34.9387   138.5377        Solar          NaN          NaN  ...
# 1  -34.9453   138.5882        Solar          NaN          NaN  ...
# 2  -35.0641   117.7977         Wind          NaN          NaN  ...
# 3  -23.7966   133.8971        Solar          NaN          NaN  ...
# 4  -34.5509   138.7659          Oil          NaN          NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512 entries, 0 to 511
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   512 non-null    object
#  1   country_long              512 non-null    object
#  2   name                      512 non-null    object
#  3   gppd_idnr                 512 non-null    object
#  4   capacity_mw               506 non-null    float64
#  5   latitude                  512 non-null    float64
#  6   longitude                 512 non-null    float64
#  7   primary_fuel              512 non-null    object
#  8   other_fuel1               0 non-null      float64
#  9   other_fuel2               0 non-null      float64
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        292 non-null    float64
#  12  owner                     495 non-null    object
# ...

# %%
df1['country'].value_counts()
# Out:
# AUS    512
# Name: country, dtype: int64

# %%
df1.drop('country_long',axis=1,inplace = True)

# %%
df1.name.value_counts()
# Out:
# Adelaide Airport                       1
# Adelaide Showgrounds                   1
# Port Hedland (Smaller)                 1
# Port Hedland                           1
# Poatina                                1
#                                       ..
# Gunning                                1
# Gullen Range Wind Farm                 1
# Griffith Solar Farm                    1
# Greenough River Solar Farm             1
# Yurralyi Maya (Karratha Seven Mile)    1
# Name: name, Length: 512, dtype: int64

# %%
df1.drop('name',axis=1,inplace = True)

# %%
df1['gppd_idnr'].value_counts()
# Out:
# AUS0000433    1
# AUS0000432    1
# AUS0000325    1
# AUS0000206    1
# AUS0000121    1
#              ..
# AUS0000040    1
# AUS0000482    1
# AUS0000511    1
# AUS0000474    1
# AUS0000218    1
# Name: gppd_idnr, Length: 512, dtype: int64

# %%
df1.drop('gppd_idnr',axis=1,inplace = True)

# %%
df1.drop('owner',axis=1,inplace =True)

# %%
df1.drop('url',axis=1,inplace=True)

# %%
df1.drop('wepp_id',axis=1,inplace=True)

# %%
df1.drop(['other_fuel1','other_fuel2','other_fuel3'],axis=1,inplace=True)

# %%
df1.drop(['source','geolocation_source','generation_gwh_2019','generation_data_source','estimated_generation_gwh'],axis=1,inplace=True)

# %%
# checking for null values in df1
df1.isnull().sum()
# Out:
# country                    0
# capacity_mw                6
# latitude                   0
# longitude                  0
# primary_fuel               0
# commissioning_year       220
# year_of_capacity_data      4
# generation_gwh_2013      259
# generation_gwh_2014      235
# generation_gwh_2015      222
# generation_gwh_2016      213
# generation_gwh_2017      219
# generation_gwh_2018      212
# dtype: int64

# %%
sns.heatmap(df1.isnull())
# Out:
# <Axes: >

# %%
df1.skew()
# Out:
# /var/folders/50/wd3xwy3j453gvdx9x80g5_140000gn/T/ipykernel_58282/149261804.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.skew()
# capacity_mw              4.677681
# latitude                 0.572775
# longitude               -0.823715
# commissioning_year      -0.927883
# year_of_capacity_data    0.000000
# generation_gwh_2013      4.584305
# generation_gwh_2014      4.773444
# generation_gwh_2015      4.982903
# generation_gwh_2016      5.108968
# generation_gwh_2017      4.721551
# generation_gwh_2018      5.059693
# dtype: float64

# %%
# Treating null values 
df1['latitude'] = df1['latitude'].fillna(df1['latitude'].mean())
df1['capacity_mw'] = df1['capacity_mw'].fillna(df1['capacity_mw'].mean())
df1['commissioning_year'] = df1['commissioning_year'].fillna(df1['commissioning_year'].mode())
df1['year_of_capacity_data'] = df1['year_of_capacity_data'].fillna(df1['year_of_capacity_data'].mode())                                                             
df1['generation_gwh_2013'] = df1['generation_gwh_2013'].fillna(df1['generation_gwh_2013'].mean())
df1['generation_gwh_2014'] = df1['generation_gwh_2014'].fillna(df1['generation_gwh_2014'].mean())
df1['generation_gwh_2015'] = df1['generation_gwh_2015'].fillna(df1['generation_gwh_2015'].mean())
df1['generation_gwh_2016'] = df1['generation_gwh_2016'].fillna(df1['generation_gwh_2016'].mean())
df1['generation_gwh_2017'] = df1['generation_gwh_2017'].fillna(df1['generation_gwh_2017'].mean())
df1['generation_gwh_2018'] = df1['generation_gwh_2018'].fillna(df1['generation_gwh_2018'].mean())

# %%
df1['year_of_capacity_data'].nunique()
# Out:
# 1

# %%
df1['commissioning_year'] = df1['commissioning_year'].fillna(df1['commissioning_year'].median())
df1['year_of_capacity_data'] = df1['year_of_capacity_data'].fillna(df1['year_of_capacity_data'].median())

# %%
# Extract year from 'commissioning_year' column
df1['commissioning_year'] = pd.to_datetime(df1['commissioning_year'], format='%Y').dt.year

print(df1['commissioning_year'].dtypes)  # Should show int64
df1.head()
# Out:
# int64
#   country  capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0     AUS         0.11  -34.9387   138.5377        Solar                2011
# 1     AUS         1.00  -34.9453   138.5882        Solar                2001
# 2     AUS        21.60  -35.0641   117.7977         Wind                2001
# 3     AUS         0.24  -23.7966   133.8971        Solar                2004
# 4     AUS         4.00  -34.5509   138.7659          Oil                2015
#
#    year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# 0                   2019           778.488685           731.375603
# 1                   2019           778.488685           731.375603
# 2                   2019            89.595278           102.642778
# 3                   2019           778.488685           731.375603
# 4                   2019           778.488685           731.375603
#
#    generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# ...

# %%
# Extract year from 'year_of_capacity_data' column
df1['year_of_capacity_data'] = pd.to_datetime(df1['year_of_capacity_data'], format='%Y').dt.year

print(df1['year_of_capacity_data'].dtypes)  # Should show int64
df1.head()
# Out:
# int64
#   country  capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0     AUS         0.11  -34.9387   138.5377        Solar                2011
# 1     AUS         1.00  -34.9453   138.5882        Solar                2001
# 2     AUS        21.60  -35.0641   117.7977         Wind                2001
# 3     AUS         0.24  -23.7966   133.8971        Solar                2004
# 4     AUS         4.00  -34.5509   138.7659          Oil                2015
#
#    year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# 0                   2019           778.488685           731.375603
# 1                   2019           778.488685           731.375603
# 2                   2019            89.595278           102.642778
# 3                   2019           778.488685           731.375603
# 4                   2019           778.488685           731.375603
#
#    generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# ...

# %%
df1.isnull().sum()
# Out:
# country                  0
# capacity_mw              0
# latitude                 0
# longitude                0
# primary_fuel             0
# commissioning_year       0
# year_of_capacity_data    0
# generation_gwh_2013      0
# generation_gwh_2014      0
# generation_gwh_2015      0
# generation_gwh_2016      0
# generation_gwh_2017      0
# generation_gwh_2018      0
# dtype: int64

# %%
df1['year_of_capacity_data'].value_counts()
# Out:
# 2019    512
# Name: year_of_capacity_data, dtype: int64

# %%
# Power plant age 
df1['Power_plant_age']= df1['year_of_capacity_data'] - df['commissioning_year']
df1.drop(['commissioning_year','year_of_capacity_data'],axis=1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'commissioning_year'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512 entries, 0 to 511
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   country                512 non-null    object
#  1   capacity_mw            512 non-null    float64
#  2   latitude               512 non-null    float64
#  3   longitude              512 non-null    float64
#  4   primary_fuel           512 non-null    object
#  5   commissioning_year     512 non-null    int64
#  6   year_of_capacity_data  512 non-null    int64
#  7   generation_gwh_2013    512 non-null    float64
#  8   generation_gwh_2014    512 non-null    float64
#  9   generation_gwh_2015    512 non-null    float64
#  10  generation_gwh_2016    512 non-null    float64
#  11  generation_gwh_2017    512 non-null    float64
#  12  generation_gwh_2018    512 non-null    float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 52.1+ KB

# %%
df1['Power_plant_age'] = df1['Power_plant_age'].fillna(df1['Power_plant_age'].median())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Power_plant_age'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512 entries, 0 to 511
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   country                512 non-null    object
#  1   capacity_mw            512 non-null    float64
#  2   latitude               512 non-null    float64
#  3   longitude              512 non-null    float64
#  4   primary_fuel           512 non-null    object
#  5   commissioning_year     512 non-null    int64
#  6   year_of_capacity_data  512 non-null    int64
#  7   generation_gwh_2013    512 non-null    float64
#  8   generation_gwh_2014    512 non-null    float64
#  9   generation_gwh_2015    512 non-null    float64
#  10  generation_gwh_2016    512 non-null    float64
#  11  generation_gwh_2017    512 non-null    float64
#  12  generation_gwh_2018    512 non-null    float64
# dtypes: float64(9), int64(2), object(2)
# memory usage: 52.1+ KB

# %%
df1.head()
# Out:
#   country  capacity_mw  latitude  longitude primary_fuel  generation_gwh_2013  \
# 0     AUS         0.11  -34.9387   138.5377        Solar           778.488685
# 1     AUS         1.00  -34.9453   138.5882        Solar           778.488685
# 2     AUS        21.60  -35.0641   117.7977         Wind            89.595278
# 3     AUS         0.24  -23.7966   133.8971        Solar           778.488685
# 4     AUS         4.00  -34.5509   138.7659          Oil           778.488685
#
#    generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0           731.375603           719.475953           698.604391
# 1           731.375603           719.475953           698.604391
# 2           102.642778            96.555556            95.872778
# 3           731.375603           719.475953           698.604391
# 4           731.375603           719.475953           698.604391
#
#    generation_gwh_2017  generation_gwh_2018  Power_plant_age
# ...

# %%
# numerical col
numerical_df1 = df1.select_dtypes(include=['number'])

print(numerical_df1)
# Out:
#      capacity_mw  latitude  longitude  generation_gwh_2013  \
# 0           0.11  -34.9387   138.5377           778.488685
# 1           1.00  -34.9453   138.5882           778.488685
# 2          21.60  -35.0641   117.7977            89.595278
# 3           0.24  -23.7966   133.8971           778.488685
# 4           4.00  -34.5509   138.7659           778.488685
# ..           ...       ...        ...                  ...
# 507         9.00  -36.0094   145.9995            38.216111
# 508       154.00  -23.8306   151.1519           778.488685
# 509         0.24  -22.2426   131.7931           778.488685
# 510        10.95  -25.2323   130.9912            21.947500
# 511       180.00  -20.7620   116.7420           778.488685
#
#      generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0             731.375603           719.475953           698.604391
# 1             731.375603           719.475953           698.604391
# ...

# %%
# Extract categorical columns
categorical_df1 = df1.select_dtypes(include=['object', 'category'])

print(categorical_df1)
# Out:
#     country primary_fuel
# 0       AUS        Solar
# 1       AUS        Solar
# 2       AUS         Wind
# 3       AUS        Solar
# 4       AUS          Oil
# ..      ...          ...
# 507     AUS        Hydro
# 508     AUS          Gas
# 509     AUS        Solar
# 510     AUS          Gas
# 511     AUS          Gas
#
# [512 rows x 2 columns]

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df1, x='primary_fuel', order=df1['primary_fuel'].value_counts().index)
plt.title('Distribution of Primary Fuel Types')
plt.xticks(rotation=90)
plt.show()

# %%
# Distribution of capacity_mw
plt.figure(figsize=(10, 6))
sns.histplot(df1['capacity_mw'], bins=50, kde=True)
plt.title('Distribution of Capacity (MW)')
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df1.corr(), annot=True, fmt='.2f')
plt.show()
# Out:
# /var/folders/50/wd3xwy3j453gvdx9x80g5_140000gn/T/ipykernel_58282/3702008491.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df1.corr(), annot=True, fmt='.2f')

# %% [markdown]
# # INDIA

# %%
df2.head()
# Out:
#   country country_long                      name   gppd_idnr  capacity_mw  \
# 0     IND        India          ACME Solar Tower  WRI1020239          2.5
# 1     IND        India       ADITYA CEMENT WORKS  WRI1019881         98.0
# 2     IND        India  AES Saurashtra Windfarms  WRI1026669         39.2
# 3     IND        India               AGARTALA GT  IND0000001        135.0
# 4     IND        India              AKALTARA TPP  IND0000002       1800.0
#
#    latitude  longitude primary_fuel other_fuel1 other_fuel2  ...  \
# 0   28.1839    73.2407        Solar         NaN         NaN  ...
# 1   24.7663    74.6090         Coal         NaN         NaN  ...
# 2   21.9038    69.3732         Wind         NaN         NaN  ...
# 3   23.8712    91.3602          Gas         NaN         NaN  ...
# 4   21.9603    82.4091         Coal         Oil         NaN  ...
#
#    year_of_capacity_data  generation_gwh_2013 generation_gwh_2014  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    object
#  1   country_long              907 non-null    object
#  2   name                      907 non-null    object
#  3   gppd_idnr                 907 non-null    object
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    object
#  8   other_fuel1               198 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        533 non-null    float64
#  12  owner                     344 non-null    object
# ...

# %%
df2.isnull().sum()
# Out:
# country                       0
# country_long                  0
# name                          0
# gppd_idnr                     0
# capacity_mw                   0
# latitude                     46
# longitude                    46
# primary_fuel                  0
# other_fuel1                 709
# other_fuel2                 906
# other_fuel3                 907
# commissioning_year          374
# owner                       563
# source                        0
# url                           0
# geolocation_source           19
# wepp_id                     907
# year_of_capacity_data       388
# generation_gwh_2013         461
# generation_gwh_2014         503
# generation_gwh_2015         479
# generation_gwh_2016         467
# generation_gwh_2017         461
# generation_gwh_2018         454
# generation_gwh_2019         906
# generation_data_source      453
# estimated_generation_gwh    907
# dtype: int64

# %%
df2['country'].value_counts()
# Out:
# IND    907
# Name: country, dtype: int64

# %%
df2.drop('country_long',axis=1,inplace = True)
df2.drop('wepp_id',axis=1,inplace = True)
df2.drop('url',axis=1,inplace = True)
df2.drop('name',axis=1,inplace = True)
df2.drop('gppd_idnr',axis=1,inplace = True)
df2.drop('owner',axis=1,inplace =True)
df2.drop(['other_fuel1','other_fuel2','other_fuel3'],axis=1,inplace=True)
df2.drop(['source','geolocation_source','generation_gwh_2019','generation_data_source','estimated_generation_gwh'],axis=1,inplace=True)

# %%
df2.drop('url',axis=1,inplace = True)

# %%
df2.drop('wepp_id',axis=1,inplace = True)

# %%
# checking for null values in df1
df2.isnull().sum()
# Out:
# country                    0
# capacity_mw                0
# latitude                  46
# longitude                 46
# primary_fuel               0
# commissioning_year       374
# year_of_capacity_data    388
# generation_gwh_2013      461
# generation_gwh_2014      503
# generation_gwh_2015      479
# generation_gwh_2016      467
# generation_gwh_2017      461
# generation_gwh_2018      454
# dtype: int64

# %%
# Treating null values 
df2['latitude'] = df2['latitude'].fillna(df2['latitude'].mean())
df2['capacity_mw'] = df2['capacity_mw'].fillna(df2['capacity_mw'].mean())
df2['commissioning_year'] = df2['commissioning_year'].fillna(df2['commissioning_year'].mode())
df2['year_of_capacity_data'] = df2['year_of_capacity_data'].fillna(df2['year_of_capacity_data'].mode())                                                             
df2['generation_gwh_2013'] = df2['generation_gwh_2013'].fillna(df2['generation_gwh_2013'].mean())
df2['generation_gwh_2014'] = df2['generation_gwh_2014'].fillna(df2['generation_gwh_2014'].mean())
df2['generation_gwh_2015'] = df2['generation_gwh_2015'].fillna(df2['generation_gwh_2015'].mean())
df2['generation_gwh_2016'] = df2['generation_gwh_2016'].fillna(df2['generation_gwh_2016'].mean())
df2['generation_gwh_2017'] = df2['generation_gwh_2017'].fillna(df2['generation_gwh_2017'].mean())
df2['generation_gwh_2018'] = df2['generation_gwh_2018'].fillna(df2['generation_gwh_2018'].mean())

# %%
df2['longitude'] = df2['longitude'].fillna(df2['longitude'].mean())

# %%
df2['commissioning_year'] = df2['commissioning_year'].fillna(df2['commissioning_year'].median())
df2['year_of_capacity_data'] = df2['year_of_capacity_data'].fillna(df2['year_of_capacity_data'].median())

# %%
# Extract year from 'commissioning_year' column
df2['commissioning_year'] = pd.to_datetime(df2['commissioning_year'], format='%Y').dt.year

print(df2['commissioning_year'].dtypes)  # Should show int64
df2.head()

# Extract year from 'year_of_capacity_data' column
df2['year_of_capacity_data'] = pd.to_datetime(df2['year_of_capacity_data'], format='%Y').dt.year

print(df2['year_of_capacity_data'].dtypes)  # Should show int64
df2.head()
# Out:
# int64
# int64
#   country  capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0     IND          2.5   28.1839    73.2407        Solar                2011
# 1     IND         98.0   24.7663    74.6090         Coal                2001
# 2     IND         39.2   21.9038    69.3732         Wind                2001
# 3     IND        135.0   23.8712    91.3602          Gas                2004
# 4     IND       1800.0   21.9603    82.4091         Coal                2015
#
#    year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# 0                   2019           436.579872          2410.620062
# 1                   2019           436.579872          2410.620062
# 2                   2019           436.579872          2410.620062
# 3                   2019             2.414610           617.789264
# 4                   2019           436.579872          3035.550000
#
#    generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# ...

# %%
df2.isnull().sum()
# Out:
# country                  0
# capacity_mw              0
# latitude                 0
# longitude                0
# primary_fuel             0
# commissioning_year       0
# year_of_capacity_data    0
# generation_gwh_2013      0
# generation_gwh_2014      0
# generation_gwh_2015      0
# generation_gwh_2016      0
# generation_gwh_2017      0
# generation_gwh_2018      0
# dtype: int64

# %%
# Power plant age 
df2['Power_plant_age']= df2['year_of_capacity_data'] - df2['commissioning_year']
df2.drop(['commissioning_year','year_of_capacity_data'],axis=1,inplace = True)

# %%
df2['Power_plant_age'] = df2['Power_plant_age'].fillna(df2['Power_plant_age'].median())

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   country              907 non-null    object
#  1   capacity_mw          907 non-null    float64
#  2   latitude             907 non-null    float64
#  3   longitude            907 non-null    float64
#  4   primary_fuel         907 non-null    object
#  5   generation_gwh_2013  907 non-null    float64
#  6   generation_gwh_2014  907 non-null    float64
#  7   generation_gwh_2015  907 non-null    float64
#  8   generation_gwh_2016  907 non-null    float64
#  9   generation_gwh_2017  907 non-null    float64
#  10  generation_gwh_2018  907 non-null    float64
#  11  Power_plant_age      907 non-null    int64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 85.2+ KB

# %%
# numerical col
numerical_df2 = df2.select_dtypes(include=['number'])

print(numerical_df2)
# Out:
#      capacity_mw  latitude  longitude  generation_gwh_2013  \
# 0            2.5   28.1839    73.2407           436.579872
# 1           98.0   24.7663    74.6090           436.579872
# 2           39.2   21.9038    69.3732           436.579872
# 3          135.0   23.8712    91.3602             2.414610
# 4         1800.0   21.9603    82.4091           436.579872
# ..           ...       ...        ...                  ...
# 902       1600.0   16.2949    77.3568           436.579872
# 903          3.0   12.8932    78.1654             1.925000
# 904         25.5   15.2758    75.5811             2.054000
# 905         80.0   24.3500    73.7477           436.579872
# 906         16.5    9.9344    77.4768           436.579872
#
#      generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0            2410.620062          2406.769148          2449.949567
# 1            2410.620062          2406.769148          2449.949567
# ...

# %%
# Extract categorical columns
categorical_df2 = df2.select_dtypes(include=['object', 'category'])

print(categorical_df2)
# Out:
#     country primary_fuel
# 0       IND        Solar
# 1       IND         Coal
# 2       IND         Wind
# 3       IND          Gas
# 4       IND         Coal
# ..      ...          ...
# 902     IND         Coal
# 903     IND        Solar
# 904     IND         Wind
# 905     IND         Coal
# 906     IND         Wind
#
# [907 rows x 2 columns]

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df2, x='primary_fuel', order=df2['primary_fuel'].value_counts().index)
plt.title('Distribution of Primary Fuel Types')
plt.xticks(rotation=90)
plt.show()

# %%
# Distribution of capacity_mw
plt.figure(figsize=(10, 6))
sns.histplot(df2['capacity_mw'], bins=50, kde=True)
plt.title('Distribution of Capacity (MW)')
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df2.corr(), annot=True, fmt='.2f')
plt.show()
# Out:
# /var/folders/50/wd3xwy3j453gvdx9x80g5_140000gn/T/ipykernel_58282/2579005883.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df2.corr(), annot=True, fmt='.2f')

# %% [markdown]
# # USA

# %%
df3.head()
# Out:
#   country  capacity_mw  latitude  longitude primary_fuel  generation_gwh_2013  \
# 0     USA          0.0   41.6327   -71.4963        Solar           563.712786
# 1     USA          2.0   41.0930   -73.9828        Solar           563.712786
# 2     USA          0.0   36.2838   -80.8434        Solar           563.712786
# 3     USA          0.0   36.2167   -80.5525        Solar           563.712786
# 4     USA          0.0   36.1475   -80.6561        Solar           563.712786
#
#    generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0           527.240856           507.402362           452.301744
# 1           527.240856           507.402362           452.301744
# 2           527.240856           507.402362           452.301744
# 3           527.240856           507.402362           452.301744
# 4           527.240856           507.402362           452.301744
#
#    generation_gwh_2017  generation_gwh_2018  Power_plant_age
# ...

# %%
df3.isnull().sum()
# Out:
# country                0
# capacity_mw            0
# latitude               0
# longitude              0
# primary_fuel           0
# generation_gwh_2013    0
# generation_gwh_2014    0
# generation_gwh_2015    0
# generation_gwh_2016    0
# generation_gwh_2017    0
# generation_gwh_2018    0
# Power_plant_age        0
# dtype: int64

# %%
df3['country'].value_counts()
# Out:
# USA    11879
# Name: country, dtype: int64

# %%
df3.drop('country_long',axis=1,inplace = True)
df3.drop('wepp_id',axis=1,inplace = True)
df3.drop('url',axis=1,inplace = True)
df3.drop('name',axis=1,inplace = True)
df3.drop('gppd_idnr',axis=1,inplace = True)
df3.drop('owner',axis=1,inplace =True)
df3.drop(['other_fuel1','other_fuel2','other_fuel3'],axis=1,inplace=True)
df3.drop(['source','geolocation_source','generation_gwh_2019','generation_data_source','estimated_generation_gwh'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[251], line 1
# ----> 1 df3.drop('country_long',axis=1,inplace = True)
#       2 df3.drop('wepp_id',axis=1,inplace = True)
#       3 df3.drop('url',axis=1,inplace = True)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df3.isnull().sum()
# Out:
# country                0
# capacity_mw            0
# latitude               0
# longitude              0
# primary_fuel           0
# generation_gwh_2013    0
# generation_gwh_2014    0
# generation_gwh_2015    0
# generation_gwh_2016    0
# generation_gwh_2017    0
# generation_gwh_2018    0
# Power_plant_age        0
# dtype: int64

# %%
# Treating null values 
df3['latitude'] = df3['latitude'].fillna(df3['latitude'].mean())
df3['longitude'] = df3['longitude'].fillna(df3['longitude'].mean())
df3['primary_fuel'] = df3['primary_fuel'].fillna(df3['primary_fuel'].mode())
df3['generation_gwh_2013'] = df3['generation_gwh_2013'].fillna(df3['generation_gwh_2013'].mean())
df3['generation_gwh_2014'] = df3['generation_gwh_2014'].fillna(df3['generation_gwh_2014'].mean())
df3['generation_gwh_2015'] = df3['generation_gwh_2015'].fillna(df3['generation_gwh_2015'].mean())
df3['generation_gwh_2016'] = df3['generation_gwh_2016'].fillna(df3['generation_gwh_2016'].mean())
df3['generation_gwh_2017'] = df3['generation_gwh_2017'].fillna(df3['generation_gwh_2017'].mean())
df3['generation_gwh_2018'] = df3['generation_gwh_2018'].fillna(df3['generation_gwh_2018'].mean())

# %%
df3['commissioning_year'] = df3['commissioning_year'].fillna(df3['commissioning_year'].median())
df3['year_of_capacity_data'] = df3['year_of_capacity_data'].fillna(df3['year_of_capacity_data'].median())

# %%
# Extract year from 'commissioning_year' column
df3['commissioning_year'] = pd.to_datetime(df3['commissioning_year'], format='%Y').dt.year

print(df3['commissioning_year'].dtypes)  # Should show int64
df3.head()

# Extract year from 'year_of_capacity_data' column
df3['year_of_capacity_data'] = pd.to_datetime(df3['year_of_capacity_data'], format='%Y').dt.year

print(df3['year_of_capacity_data'].dtypes)  # Should show int64
df3.head()
# Out:
# int64
# int64
#   country  capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0     USA          0.0   41.6327   -71.4963        Solar                2017
# 1     USA          2.0   41.0930   -73.9828        Solar                2016
# 2     USA          0.0   36.2838   -80.8434          NaN                2009
# 3     USA          0.0   36.2167   -80.5525          NaN                2009
# 4     USA          0.0   36.1475   -80.6561          NaN                2009
#
#    year_of_capacity_data  generation_gwh_2013  generation_gwh_2014  \
# 0                   2019           563.712786           527.240856
# 1                   2019           563.712786           527.240856
# 2                   2019           563.712786           527.240856
# 3                   2019           563.712786           527.240856
# 4                   2019           563.712786           527.240856
#
#    generation_gwh_2015  generation_gwh_2016  generation_gwh_2017  \
# ...

# %%
df2.isnull().sum()
# Out:
# country                0
# capacity_mw            0
# latitude               0
# longitude              0
# primary_fuel           0
# generation_gwh_2013    0
# generation_gwh_2014    0
# generation_gwh_2015    0
# generation_gwh_2016    0
# generation_gwh_2017    0
# generation_gwh_2018    0
# Power_plant_age        0
# dtype: int64

# %%
# Power plant age 
df3['Power_plant_age']= df3['year_of_capacity_data'] - df3['commissioning_year']
df3.drop(['commissioning_year','year_of_capacity_data'],axis=1,inplace = True)

# %%
df3['Power_plant_age'] = df3['Power_plant_age'].fillna(df3['Power_plant_age'].median())

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11879 entries, 0 to 11878
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   country              11879 non-null  object
#  1   capacity_mw          11879 non-null  float64
#  2   latitude             11879 non-null  float64
#  3   longitude            11879 non-null  float64
#  4   primary_fuel         9876 non-null   object
#  5   generation_gwh_2013  11879 non-null  float64
#  6   generation_gwh_2014  11879 non-null  float64
#  7   generation_gwh_2015  11879 non-null  float64
#  8   generation_gwh_2016  11879 non-null  float64
#  9   generation_gwh_2017  11879 non-null  float64
#  10  generation_gwh_2018  11879 non-null  float64
#  11  Power_plant_age      11879 non-null  int64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 1.1+ MB

# %%
df3['primary_fuel'].fillna(df3['primary_fuel'].mode()[0], inplace=True)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11879 entries, 0 to 11878
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   country              11879 non-null  object
#  1   capacity_mw          11879 non-null  float64
#  2   latitude             11879 non-null  float64
#  3   longitude            11879 non-null  float64
#  4   primary_fuel         11879 non-null  object
#  5   generation_gwh_2013  11879 non-null  float64
#  6   generation_gwh_2014  11879 non-null  float64
#  7   generation_gwh_2015  11879 non-null  float64
#  8   generation_gwh_2016  11879 non-null  float64
#  9   generation_gwh_2017  11879 non-null  float64
#  10  generation_gwh_2018  11879 non-null  float64
#  11  Power_plant_age      11879 non-null  int64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 1.1+ MB

# %%
# numerical col
numerical_df3 = df3.select_dtypes(include=['number'])

print(numerical_df3)
# Out:
#        capacity_mw  latitude  longitude  generation_gwh_2013  \
# 0              0.0   41.6327   -71.4963           563.712786
# 1              2.0   41.0930   -73.9828           563.712786
# 2              0.0   36.2838   -80.8434           563.712786
# 3              0.0   36.2167   -80.5525           563.712786
# 4              0.0   36.1475   -80.6561           563.712786
# ...            ...       ...        ...                  ...
# 11874          3.4   42.8869   -76.9683             3.671000
# 11875          1.0   44.3195   -92.6703           563.712786
# 11876          0.0   44.0460   -92.7600           563.712786
# 11877          0.0   39.7373  -105.0170             0.000000
# 11878          9.8   40.5606  -112.0478            12.968000
#
#        generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# 0               527.240856           507.402362           452.301744
# 1               527.240856           507.402362           452.301744
# ...

# %%
# Extract categorical columns
categorical_df3 = df3.select_dtypes(include=['object', 'category'])

print(categorical_df3)
# Out:
#       country primary_fuel
# 0         USA        Solar
# 1         USA        Solar
# 2         USA        Solar
# 3         USA        Solar
# 4         USA        Solar
# ...       ...          ...
# 11874     USA         Wind
# 11875     USA        Solar
# 11876     USA        Solar
# 11877     USA        Solar
# 11878     USA          Gas
#
# [11879 rows x 2 columns]

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df3, x='primary_fuel', order=df3['primary_fuel'].value_counts().index)
plt.title('Distribution of Primary Fuel Types')
plt.xticks(rotation=90)
plt.show()

# %%
# Distribution of capacity_mw
plt.figure(figsize=(10, 6))
sns.histplot(df3['capacity_mw'], bins=50, kde=True)
plt.title('Distribution of Capacity (MW)')
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df3.corr(), annot=True, fmt='.2f')
plt.show()
# Out:
# /var/folders/50/wd3xwy3j453gvdx9x80g5_140000gn/T/ipykernel_58282/745439481.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df3.corr(), annot=True, fmt='.2f')

# %%
df = combined_df = pd.concat([df1,df2,df3],ignore_index=True)

# %%
# Plot primary_fuel vs country
plt.figure(figsize=(14, 8))
sns.countplot(data=df, x='country', hue='primary_fuel', palette='Set2')
plt.title('Distribution of Primary Fuel Types by Country')
plt.xlabel('Country')
plt.ylabel('Count')
plt.legend(title='Primary Fuel')
plt.show()

sns.countplot()
# Out:
# <Axes: ylabel='count'>

# %%
# Group by country and primary fuel, then sum the capacities
fuel_use = df.groupby(['country', 'primary_fuel'])['capacity_mw'].sum().reset_index()

# Find the highest primary fuel use by each country
highest_fuel_use = fuel_use.loc[fuel_use.groupby('country')['capacity_mw'].idxmax()]

# Display the result
highest_fuel_use
# Out:
#    country primary_fuel  capacity_mw
# 1      AUS         Coal     25543.00
# 9      IND         Coal    205839.22
# 19     USA          Gas    546437.10

# %%
print(df.isnull().sum())
# Out:
# capacity_mw                  0
# latitude                     0
# longitude                    0
# generation_gwh_2013          0
# generation_gwh_2014          0
# generation_gwh_2015          0
# generation_gwh_2016          0
# generation_gwh_2017          0
# generation_gwh_2018          0
# Power_plant_age              0
# primary_fuel_Biomass         0
# primary_fuel_Coal            0
# primary_fuel_Cogeneration    0
# primary_fuel_Gas             0
# primary_fuel_Geothermal      0
# primary_fuel_Hydro           0
# primary_fuel_Nuclear         0
# primary_fuel_Oil             0
# primary_fuel_Other           0
# primary_fuel_Petcoke         0
# primary_fuel_Solar           0
# primary_fuel_Storage         0
# primary_fuel_Waste           0
# primary_fuel_Wind            0
# country_AUS                  0
# country_IND                  0
# country_USA                  0
# dtype: int64

# %%
df.describe()
# Out:
#         capacity_mw      latitude     longitude  generation_gwh_2013  \
# count  13298.000000  13298.000000  13298.000000         13298.000000
# mean     117.743067     35.014563    -73.319561           563.310899
# std      347.090763     15.421490     63.318320          1491.430377
# min        0.000000    -42.888300   -171.712400          -947.600000
# 25%        1.500000     33.875825   -104.583400            15.063500
# 50%        5.500000     38.383400    -87.307700           533.092500
# 75%       52.975000     42.166025    -75.391000           563.712786
# max     6809.000000    425.246100    153.434100         31431.080000
#
#        generation_gwh_2014  generation_gwh_2015  generation_gwh_2016  \
# count         13298.000000         13298.000000         13298.000000
# mean            663.557741           645.115353           598.035954
# std            1687.590642          1700.734868          1696.601056
# ...

# %%
sns.countplot(data=df, x='primary_fuel', order=df['primary_fuel'].value_counts().index)
plt.title('Distribution of Primary Fuel Types')
plt.xticks(rotation=90)
plt.show()

# Distribution of capacity_mw
plt.figure(figsize=(10, 6))
sns.histplot(df['capacity_mw'], bins=50, kde=True)
plt.title('Distribution of Capacity (MW)')
plt.show()

# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, fmt='.2f')
plt.show()
# Out:
# /var/folders/50/wd3xwy3j453gvdx9x80g5_140000gn/T/ipykernel_58282/1743193188.py:14: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, fmt='.2f')

# %%
# Convert categorical columns to numerical using one-hot encoding
df = pd.get_dummies(df, columns=['primary_fuel','country'])

# %%
# Features and target variables for primary fuel and capacity
X_fuel = df.drop(columns=['primary_fuel','capacity_mw'],axis=1)
y_fuel = df['primary_fuel']
X_capacity = df.drop(columns=['capacity_mw', 'primary_fuel'],axis=1)
y_capacity = df['capacity_mw']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[244], line 2
#       1 # Features and target variables for primary fuel and capacity
# ----> 2 X_fuel = df.drop(columns=['primary_fuel','capacity_mw'],axis=1)
#       3 y_fuel = df['primary_fuel']
#       4 X_capacity = df.drop(columns=['capacity_mw', 'primary_fuel'],axis=1)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
df.columns
# Out:
# Index(['capacity_mw', 'latitude', 'longitude', 'generation_gwh_2013',
#        'generation_gwh_2014', 'generation_gwh_2015', 'generation_gwh_2016',
#        'generation_gwh_2017', 'generation_gwh_2018', 'Power_plant_age',
#        'primary_fuel_Biomass', 'primary_fuel_Coal',
#        'primary_fuel_Cogeneration', 'primary_fuel_Gas',
#        'primary_fuel_Geothermal', 'primary_fuel_Hydro', 'primary_fuel_Nuclear',
#        'primary_fuel_Oil', 'primary_fuel_Other', 'primary_fuel_Petcoke',
#        'primary_fuel_Solar', 'primary_fuel_Storage', 'primary_fuel_Waste',
#        'primary_fuel_Wind', 'country_AUS', 'country_IND', 'country_USA'],
#       dtype='object')

# %%
# Split the data into training and testing sets for primary fuel and capacity models
from sklearn.model_selection import train_test_split

# %%
X_train_fuel, X_test_fuel, y_train_fuel, y_test_fuel = train_test_split(X_fuel, y_fuel, test_size=0.2, random_state=42)
X_train_capacity, X_test_capacity, y_train_capacity, y_test_capacity = train_test_split(X_capacity, y_capacity, test_size=0.2, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[283], line 1
# ----> 1 X_train_fuel, X_test_fuel, y_train_fuel, y_test_fuel = train_test_split(X_fuel, y_fuel, test_size=0.2, random_state=42)
#       2 X_train_capacity, X_test_capacity, y_train_capacity, y_test_capacity = train_test_split(X_capacity, y_capacity, test_size=0.2, random_state=42)
#
# NameError: name 'X_fuel' is not defined

# %%
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor, GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score

# %%
models_fuel = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Gradient Boosting': GradientBoostingClassifier()
}

# %%
models_capacity = {
    'Linear Regression': LinearRegression(),
    'Decision Tree': DecisionTreeRegressor(),
    'Random Forest': RandomForestRegressor(),
    'Gradient Boosting': GradientBoostingRegressor()
}

# %%
def evaluate_models_classification(models, X_train, y_train, X_test, y_test):
    results = {}
    for model_name, model in models.items():
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        accuracy = accuracy_score(y_test, y_pred)
        results[model_name] = {'Accuracy': accuracy}
        print(f"{model_name} - Accuracy: {accuracy:.2f}")
    return results

# %%
def evaluate_models_regression(models, X_train, y_train, X_test, y_test):
    results = {}
    for model_name, model in models.items():
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        mse = mean_squared_error(y_test, y_pred)
        r2 = r2_score(y_test, y_pred)
        results[model_name] = {'MSE': mse, 'R2': r2}
        print(f"{model_name} - MSE: {mse:.2f}, R2: {r2:.2f}")
    return results

# %%
# Evaluate models for primary fuel prediction
print("model selection for Primary Fuel:")
results_fuel = evaluate_models_classification(models_fuel, X_train_fuel, y_train_fuel, X_test_fuel, y_test_fuel)

# Evaluate models for capacity prediction
print("\nmodel selection for Capacity:")
results_capacity = evaluate_models_regression(models_capacity, X_train_capacity, y_train_capacity, X_test_capacity, y_test_capacity)
